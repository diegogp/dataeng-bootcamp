# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:root@postgres:5432/ny_taxi')

# %%
engine.connect()

# %%
pd.read_sql("select * from pg_catalog.pg_tables where schemaname != 'pg_catalog' and schemaname != 'information_schema';"
            , con=engine)
# Out:
#   schemaname         tablename tableowner tablespace  hasindexes  hasrules  \
# 0     public  yellow_taxi_data   postgres       None       False     False
#
#    hastriggers  rowsecurity
# 0        False        False

# %%
df = pd.read_parquet("/code/raw_data/yellow_tripdata_2021-01.parquet")

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data'))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL,
#   "airport_fee" REAL
# )

# %%
# %time
df.to_sql(name='yellow_taxi_data', con=engine, index=False, if_exists='replace', chunksize=100000)
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 23.4 µs
# 13769

# %%
pd.read_sql("select * from yellow_taxi_data limit 100;"
            , con=engine)
# Out:
#     VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0          1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1          1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2          1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3          1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4          2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ..       ...                  ...                   ...              ...
# 95         2  2021-01-01 00:12:41   2021-01-01 00:26:47              1.0
# 96         2  2021-01-01 00:23:29   2021-01-01 00:35:03              2.0
# 97         2  2021-01-01 00:46:17   2021-01-01 00:54:25              2.0
# 98         2  2021-01-01 00:28:16   2021-01-01 00:51:44              1.0
# 99         2  2021-01-01 00:42:35   2021-01-01 00:54:41              3.0
#
#     trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# ...

# %%
pd.read_sql("select count(1) from yellow_taxi_data;"
            , con=engine)
# Out:
#      count
# 0  1369769
